# %% [markdown]
# <a href="https://colab.research.google.com/github/seetach/python-data-ml-journey/blob/main/Day01_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 1 - Python Basics
#
# ## Introduction to Python
#
# Python is a most popular programming language in the world.
#
# ## print() Function

# %%
print("Hello,World!")
# Out:
# Hello,World!

# %% [markdown]
# print() is a built-in Python function

# %% [markdown]
# We can use ("") or ('')

# %%
print("my name is Seeta")
# Out:
# my name is Seeta

# %%
print("i am learning python")
# Out:
# i am learning python

# %%
print('my name is Maha')
# Out:
# my name is Maha

# %% [markdown]
# ##Variables
# A variable is a container that stores data.

# %%
name = "Seeta"
age = 25

print(name)
print(age)
# Out:
# Seeta
# 25

# %% [markdown]
# Explanation:
# name is a variable.
# "Seeta" is a string value.

# %% [markdown]
# ##Data Types
# Python stores different data types
#
# #string(str) ---- Text Data
# name="seeta"
# #integer(int) --- Whole Numbers
# age=25
# #Float(float) --- Decimal Numbers
# height=5.4
# #Boolean(Bool) --- True or False
# Is_student=True

# %%
name="seeta"
age=25
height=5.4
Is_student="True"

print_function=name,age,height,Is_student
print(print_function)
# Out:
# ('seeta', 25, 5.4, 'True')

# %%
#taking user inputs
name = input("enter your name:")
print('Welcome' , name)
# Out:
# enter your name:seeta
# Welcome seeta

# %%
name = input("enter your name:")
age = input("enter your age:")
course = input("enter your course:")

print("name:", name)
print("age:", age)
print("course:", course)
# Out:
# enter your name:seeta
# enter your age:25
# enter your course:python
# name: seeta
# age: 25
# course: python
